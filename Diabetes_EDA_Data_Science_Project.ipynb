# %% [markdown]
# <a href="https://colab.research.google.com/github/risshabhraj/EDA_Diabetes/blob/main/Diabetes_EDA_Data_Science_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **EDA on Diabetes dataset**
#
# ---

# %% [markdown]
# > **1->  Importing the dataset and the necessary libraries**
#
# ---

# %% [markdown]
# > Numpy is used here to perform statistical and algebraic operations.
#
# > Pandas is used here to read CSV file and for data processing.
#
# > Seaborn is used here for data visualization, it provides high level   interface for drawing informative statistical graphics.
#
# > Matplotlib is used here for plotting data with labels.
#
# > Importing warnings to ignore or filter any warning occuring in the program.

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **1.1-> Data Loading**

# %%
diabetes_data = pd.read_csv("diabetes.csv")
diabetes_data
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# **1.2-> Statistical Summary & Checking Datatype**

# %% [markdown]
# -> Statistical Summary has been performed here to get summarized and organized information of data.
#
# -> Statistical summary include **mean, median, mode, minimum value, maximum value, range, standard deviation** etc.
#
# -> Checking the datatype is important here because data could be stored in integer or string which may cause errors while doing the **data  visualization**

# %% [markdown]
# * **head()** function gives us the first n rows, n could be defined by the user or by default it gives us first 5 rows.

# %%
diabetes_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %% [markdown]
# * **tail()** function gives us the last n rows, n could be defined by the user or by default it gives us last 5 rows.

# %%
diabetes_data.tail()
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [5 rows x 9 columns]

# %% [markdown]
# * **shape** funtion returns the shape of an array, the numbers given out as an ouput denotes the lenght of the corresponding array dimension.

# %% [markdown]
# From the above ouputs we get to know that the features which will help us to predict wether a persion is diabetic or not :-
# * Pregnancies
# * Glucose
# * Blood Pressure
# * Isulin
# * BMI
# * Diabetes Pedigree Function
# * Age (Years)
# * Outcome

# %%
diabetes_data.shape
# Out:
# (768, 9)

# %% [markdown]
# * **describe** funtion computes a summary statitics pertaining to the dataframe columns. It gives us mean, std and IQR values.

# %%
diabetes_data.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %% [markdown]
# * **info** function gives us a concise summary of a dataframe including the index, dtype, columns, non-null values, it is used here to find if the dataframe contains any null value.

# %%
diabetes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# * **value_counts** funtion returns a series containing **counts of unique values**. The resulting object will be in **descending** order so that the first element is the most frequently-occurring element. **Excludes NA** values by default.

# %%
diabetes_data['Age'].value_counts()
# Out:
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# 28    35
# 26    33
# 27    32
# 29    29
# 31    24
# 41    22
# 30    21
# 37    19
# 42    18
# 33    17
# 32    16
# 36    16
# 38    16
# 45    15
# 34    14
# 40    13
# 43    13
# 46    13
# 39    12
# 35    10
# 50     8
# 44     8
# 51     8
# 52     8
# 58     7
# 47     6
# 54     6
# 57     5
# 60     5
# 48     5
# 49     5
# 53     5
# 55     4
# 62     4
# 63     4
# 66     4
# 56     3
# 59     3
# 65     3
# 67     3
# 61     2
# 69     2
# 72     1
# 64     1
# 68     1
# 70     1
# 81     1
# Name: Age, dtype: int64

# %% [markdown]
# From the output we can infer that **22 Age Group** is the most frequently occuring & **81 Age Group** the least occuring in the dataframe.

# %%
diabetes_data['Glucose'].value_counts()
# Out:
# 100    17
# 99     17
# 129    14
# 125    14
# 111    14
#        ..
# 177     1
# 172     1
# 169     1
# 160     1
# 199     1
# Name: Glucose, Length: 136, dtype: int64

# %% [markdown]
# > **2-> Dropping Irrelevant columns**
#
# ---

# %% [markdown]
# * **Dropping Irrelevant Columns** is an important step to make the final output to be more accurate and precise. By dropping the irrelevant columns we are removing the columns which we will not use further to decide or predict the result and we do this so that we give more focus to the columns which can be usefull and will help in further calculations or viualizations.

# %% [markdown]
# Since here all the columns are important in the prediction we will not be dropping any columns.

# %% [markdown]
# > **3-> Checking for any duplicates in the data, checking for null values and missing data.**
#
# ---

# %% [markdown]
# Checking for duplicate data and null values are one of the most important steps as this could bring a huge difference in data viualization and final results.

# %% [markdown]
# * Large datasets contains duplicate data and so by using **duplicated** function we find the duplicate data.

# %%
duplicate_rows_diabetes_data =  diabetes_data[diabetes_data.duplicated()]
duplicate_rows_diabetes_data.shape
# Out:
# (0, 9)

# %% [markdown]
# We can observe from the above output that there are **0 rows & 9 columns** having duplicate data.

# %% [markdown]
# * By using **drop_duplicates** function we drop the duplicate data that we found using **duplicated** function.

# %%
diabetes_data = diabetes_data.drop_duplicates()
diabetes_data.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
diabetes_data.shape
# Out:
# (768, 9)

# %% [markdown]
# * **isnull** function is used here to detect the missing values in the given series object, it returns a boolean same-sized object indicating if the values are NA. **Missing** values gets mapped to **True** and **non-missing** value gets mapped to **False.**

# %%
diabetes_data.isnull()
# Out:
#      Pregnancies  Glucose  ...    Age  Outcome
# 0          False    False  ...  False    False
# 1          False    False  ...  False    False
# 2          False    False  ...  False    False
# 3          False    False  ...  False    False
# 4          False    False  ...  False    False
# ..           ...      ...  ...    ...      ...
# 763        False    False  ...  False    False
# 764        False    False  ...  False    False
# 765        False    False  ...  False    False
# 766        False    False  ...  False    False
# 767        False    False  ...  False    False
#
# [768 rows x 9 columns]

# %% [markdown]
# * **isnull().sum()** returns the number of missing values in the data set.

# %%
diabetes_data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# From the above output we concude that there are no null values in the data set.

# %% [markdown]
# **3.1-> Filling the mising data.**

# %% [markdown]
# To fill the missing data we use **fillna** function to fill **0** using specified method. Here we are using **mean** to fill the data because the missing data in each columns are of **integer type.**

# %%
diabetes_data['Pregnancies'].fillna(diabetes_data['Pregnancies'].mean(), inplace = True)

# %%
diabetes_data['Glucose'].fillna(diabetes_data['Glucose'].mean(), inplace = True)

# %%
diabetes_data['BloodPressure'].fillna(diabetes_data['BloodPressure'].mean(), inplace = True)

# %%
diabetes_data['SkinThickness'].fillna(diabetes_data['SkinThickness'].mean(), inplace = True)

# %%
diabetes_data['Insulin'].fillna(diabetes_data['Insulin'].mean(), inplace = True)

# %%
diabetes_data['BMI'].fillna(diabetes_data['BMI'].mean(), inplace = True)

# %%
diabetes_data['Age'].fillna(diabetes_data['Age'].mean(), inplace = True)

# %%
diabetes_data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# > **4-> Checking for Outliers & Plotting Graph**
#
# ---

# %% [markdown]
# The difference between a good and an average machine learning model is often its **ability to clean data**. One of the biggest challenges in data cleaning is the **identification and treatment of outliers.**

# %% [markdown]
# **In statistics, an outlier is an observation point that is distant from other observations.** And this point can effect the final results, graphs and the plots and so checking for outliers and removing them becomes a vital step.

# %% [markdown]
# There can be many reasons for the presence of **outliers** in the data. Sometimes the **outliers** may be genuine, while in other cases, they could exist because of **data entry errors**.

# %%
diabetes_data.boxplot(figsize = (15,15))

# %% [markdown]
# We can observe from the above plot that there are points that are distant from other observations and this will effect our plots and results.

# %%
diabetes_data.hist(figsize = (10 , 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9dd0f88e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9dd0fb5390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9dd0f6ca10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f9dd0f2e0d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9dd0ee5750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9dd0e99dd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f9dd0e5c510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9dd0e11ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9dd0e11b10>]],
#       dtype=object)

# %% [markdown]
# Plotting **boxplot** for each columns gives us a clear view of points that are in distant from other observations. And by looking at the plot we can make better formulas or algorithms to **remove outliers** so that we don't remove any important observations or points which will effect negatively in data visualization and predictions.

# %%
sns.boxplot(x = diabetes_data['Age'])

# %% [markdown]
# * A **box plot** is a method for graphically depicting groups of numerical data through their **quartiles**. Box plots may also have lines extending vertically from the boxes (whiskers) indicating variability outside the upper and lower quartiles.

# %%
sns.boxplot(x = diabetes_data['Pregnancies'])

# %%
sns.boxplot(x = diabetes_data['BloodPressure'])

# %%
sns.boxplot(x = diabetes_data['BMI'])

# %%
sns.boxplot(x = diabetes_data['DiabetesPedigreeFunction'])

# %% [markdown]
# > **Identifying Outliers with Interquartile Range (IQR)**

# %% [markdown]
# The **interquartile range (IQR)** is a measure of statistical dispersion and is calculated as the difference between the **75th and 25th percentiles**. It is represented by the formula **IQR = Q3 − Q1.**

# %%
Q1 = diabetes_data.quantile(0.25)
Q3 = diabetes_data.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Pregnancies                   5.0000
# Glucose                      41.2500
# BloodPressure                18.0000
# SkinThickness                32.0000
# Insulin                     127.2500
# BMI                           9.3000
# DiabetesPedigreeFunction      0.3825
# Age                          17.0000
# Outcome                       1.0000
# dtype: float64

# %% [markdown]
# The above output prints the IQR scores, which can be used to **detect outliers.**

# %%
diabetes_data1 = diabetes_data[-((diabetes_data < (Q1 - 1.5*IQR)) | (diabetes_data > (Q3 + 1.5*IQR))).any(axis = 1)]
diabetes_data1.shape
# Out:
# (639, 9)

# %% [markdown]
# If we compare the shape of **diabetes_data & diabetes_data1** , we can obsereve the difference in number of rows, which means we have removed the outliers or the data/points which were in distant from other observations.

# %% [markdown]
# **Another Method**
#
# min_threshold = diabetes_data.Age.quantile(0.25)
#
# max_threshold = diabetes_data.Age.quantile(0.75)
#
# diabetes_data_new = diabetes_data[(diabetes_data.Age<max_threshold)&(diabetes_data.Age>min_threshold)]
#
# diabetes_data_new.shape
#
# **The result using this method was not satisfactory.**

# %% [markdown]
# We draw different graphs and plot the data because it illustrate **relationships in the data**, and also it gives us an idea that our data is in which **range**. We have drawn two graphs of **Age** column. the First graph is based on the data which **contains outliers and duplicate rows** & the second graph has been plotted on data after **removing outliers and duplicate data.**

# %%
sns.kdeplot(data= diabetes_data['Age'], label = "Age" ,shade = True)

# %%
sns.kdeplot(data= diabetes_data1['Age'], label = "Age" ,shade = True)

# %% [markdown]
# * We can clearly observe the differences.

# %%
diabetes_data['Age'].hist(bins = 8)

# %% [markdown]
# Similarly, the bar graph gives us the range of **Age**, which can be observed from the graph below.

# %%
diabetes_data1['Age'].hist(bins=8)

# %% [markdown]
# > **5-> Plotting the Correlation Matrix**
#
# ---

# %% [markdown]
# A **correlation matrix** is a table showing **correlation coefficients** between variables. Each cell in the table shows the correlation between two variables.

# %% [markdown]
# A **correlation matrix** is used to **summarize data**, as an input into a more advanced analysis, and as a diagnostic for advanced analyses.

# %% [markdown]
# * **corr()** function is used to find the pairwise correlation of all columns in the dataframe. Any na values are automatically excluded.

# %%
diabetes_data1.corr()
# Out:
#                           Pregnancies   Glucose  ...       Age   Outcome
# Pregnancies                  1.000000  0.142093  ...  0.567438  0.227987
# Glucose                      0.142093  1.000000  ...  0.286682  0.492740
# BloodPressure                0.210666  0.238754  ...  0.354036  0.183298
# SkinThickness               -0.094425 -0.004609  ... -0.143376  0.030676
# Insulin                     -0.114510  0.248225  ... -0.089535  0.097746
# BMI                          0.036958  0.192504  ...  0.063370  0.269371
# DiabetesPedigreeFunction     0.009289  0.066530  ...  0.030081  0.179072
# Age                          0.567438  0.286682  ...  1.000000  0.263344
# Outcome                      0.227987  0.492740  ...  0.263344  1.000000
#
# [9 rows x 9 columns]

# %% [markdown]
# The correlation of a variable with itself is 1 and if we plot the above output in **heatmap** we can observe the ouput better.

# %% [markdown]
# > **6-> Performing EDA & plotting different graphs.**
#
# ---

# %% [markdown]
# A **heatmap** is a **two-dimensional graphical representation** of data where the individual values that are contained in a **matrix** are represented as colors.

# %% [markdown]
# The **seaborn** python package allows the creation of **annotated heatmaps** which can be tweaked using **Matplotlib** tools as per the creator's requirement.

# %%
plt.figure(figsize=(20,9))
a = sns.heatmap(diabetes_data1.corr(), annot=True, fmt='.2f')

# %% [markdown]
# * Lighter the colour higher will be the positive correlation & the darker the colour higher will be the negative correlation.

# %% [markdown]
# From the heat map we observe that :-
#
# **-> Positive Correlation between :-**
#
#   * Pregnancy & Age
#   * Glucose & Outcome
#   * Skinthickness & Insulin
#   * BMI & Skinthickness
#
# **-> Negative Correlation between :-**
#
#   * Skinthickness & Age
#   * Pregnancies & Insulin
#   * Pregnancies & Skinthickness
#   * Insulin & Blood Pressure

# %%
diabetes_data1['Outcome'].value_counts(normalize=True).plot(figsize=(6, 6),kind='bar',color='green')
plt.title("Number of Diabetic Patients")
plt.ylabel('Count')
plt.xlabel('Outcome');

# %% [markdown]
# From the above bar graph we can conclude that around **30%** of the patients are diabetic and around **60%** non-diabetic.

# %%
plt.figure(figsize=(8, 8))
pieC=diabetes_data1['Outcome'].value_counts()
explode=(0.05, 0)
colors=['green', 'blue']
labels=['0-Non Diabetic', '1-Diabetic']
sns.set(font_scale=1.5)
plt.pie(pieC, labels=('0-Non Diabetic', '1-Diabetic'), autopct ="%.2f%%", explode=explode, colors=colors)
plt.legend(labels, loc='lower left')

# %%
diabetes_data1.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9dc53755d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9dc39fe150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9dc3a347d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f9dc39e9e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9dc39ac510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9dc3962b90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f9dc39262d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9dc38da890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9dc38da8d0>]],
#       dtype=object)

# %% [markdown]
# **Observations from the above Bar Graphs :-**
#
#
# 1. Most of the patients become Diabetic in first pregnancy
# 2. Most of the patients having glucose level between 100 & 150 are likely to become diabetic.
# 3. Most of the patients having blood pressure 75 are likely to become diabetic.
# 4. Most of the patients are of 20-25 age group.
# 5. Most of the patients having BMI between 30-40 are likely to become diabetic.

# %% [markdown]
# **Scatter plots** are used to plot data points on horizontal and vertical axis in the attempt to show how much one variable is affected by another.

# %%
fig, z = plt.subplots(figsize = (10,6))
z.scatter(diabetes_data1['Pregnancies'], diabetes_data1['Age'])
z.set_xlabel('Pregnancies')
z.set_ylabel('Age')
plt.show()

# %% [markdown]
# Here **scatter plot** has been plotted between **Age and Pregnancies** from the plot we can easily observe the relation between the two.

# %%
fig, z = plt.subplots(figsize = (10,6))
z.scatter(diabetes_data1['SkinThickness'], diabetes_data1['Insulin'])
z.set_xlabel('Skinthickness')
z.set_ylabel('Insulin')
plt.show()

# %%
plt.rcParams['figure.figsize']=(30, 10)
ax = sns.boxplot(x="BMI", y="SkinThickness", data=diabetes_data1)

# %%
sns.catplot(data=diabetes_data1, x="Age", y="Pregnancies", hue = 'Outcome', kind="point", aspect=5)

# %%
sns.catplot(data=diabetes_data1, y="Insulin", x="SkinThickness" , hue="Outcome" ,kind="point", aspect = 4, height = 8)

# %%
sns.pairplot(diabetes_data1)

# %% [markdown]
# > **7-> ML MODEL**
#
# ---

# %% [markdown]
# > **Multi-linear Regression**

# %% [markdown]
# **Multiple linear regression (MLR)**, also known simply as **multiple regression**, is a statistical technique that uses several explanatory variables to predict the outcome of a response variable.

# %%
X = diabetes_data1[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']].values
Y = diabetes_data1['Outcome'].values

# %% [markdown]
# **Feature scaling** is an important preprocessing step for **machine learning** algorithms. Standardization involves rescaling the features such that they have the properties of a standard normal distribution with a mean of zero and a standard deviation of one.

# %%
# Featur Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_Y = StandardScaler()
X = sc_X.fit_transform(X)
Y = sc_Y.fit_transform(Y.reshape(-1,1))

# %%
#splitting the dataset into the training set and test set
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %% [markdown]
# We have splitted the data in the ratio of 20:80, tet size is 20

# %%
#Fitting Multiple Linear Regression to the Training Set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Predicting the Test Set results
Y_pred = regressor.predict(X_test)
plt.scatter(Y_test, Y_pred)

# %%
sns.distplot((Y_test-Y_pred), bins =50)

# %% [markdown]
# * Through the plot we are checking the **residuals**.

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, Y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('R2 Score:', metrics.r2_score(Y_test, Y_pred))
# Out:
# Mean Absolute Error: 0.6989509868618815
# Root Mean Squared Error: 0.8578257780112354
# R2 Score: 0.3059027585634444

# %% [markdown]
# * By observing the reults from **metrics** we get to know the **Mean Absolute Error, Root Mean Squared Error, R2 Score** when we apply **multi linear regression.**

# %% [markdown]
# > **8-> Applying different algorithms and checking the output**
#
# ---

# %% [markdown]
# > **Polynomial Regression**

# %% [markdown]
# **Polynomial Regression** is a form of linear regression in which the relationship between the independent variable x and dependent variable y is modeled as an nth degree polynomial.

# %%
# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
poly_reg.fit(X_poly, Y)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Visualising the Polynomial Regression results
Y_pred = lin_reg_2.predict(poly_reg.fit_transform(X_test))
plt.scatter(Y_test, Y_pred)

# %%
sns.distplot((Y_test-Y_pred), bins =50)

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, Y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('R2 Score:', metrics.r2_score(Y_test, Y_pred))
# Out:
# Mean Absolute Error: 0.2558390968057527
# Root Mean Squared Error: 0.34570193364989527
# R2 Score: 0.8872735708023312

# %% [markdown]
# By observing the output and comparing them to the output in **multilinear regression** we can conclude that **polynomial regression performed better than MLR**.

# %% [markdown]
# There is a decrease in Mean Absolute Error and Root Mean Squared Error & a increase in **R2** score.

# %% [markdown]
# > **Support Vector Machine (SVR)**

# %% [markdown]
# **Support Vector Machine** can also be used as a regression method, maintaining all the main features that characterize the algorithm (maximal margin). The Support Vector Regression (SVR) uses the same principles as the SVM for classification, with only a few minor differences.

# %%
# Fitting SVR to the dataset
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X_train, Y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
# Predicting a new result
Y_pred = regressor.predict(X_test)
plt.scatter(Y_test, Y_pred)

# %%
sns.distplot((Y_test-Y_pred), bins =50)

# %% [markdown]
# We can observe the changes in graph of **SVM** from the graph of **MLR and Polynomial Regression.**

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, Y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('R2 Score:', metrics.r2_score(Y_test, Y_pred))
# Out:
# Mean Absolute Error: 0.5943857880059044
# Root Mean Squared Error: 0.8757271741225683
# R2 Score: 0.276631179775052

# %% [markdown]
# There is an increase in Mean Absolute Error and Root Mean Squared Error & a decrease in **R2** score.

# %% [markdown]
# Also a change can be observed in the **metrics** values, by which we can conclude **SVM** performed poorer than **MLR and Polynomial Regression.**

# %% [markdown]
# > **Decission Tree**

# %% [markdown]
# **Decision tree** builds regression or classification models in the form of a tree structure. It breaks down a dataset into smaller and smaller subsets while at the same time an associated decision tree is incrementally developed. The final result is a tree with decision nodes and leaf nodes.

# %%
# Fitting Decision Tree Regression to the dataset
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=0, splitter='best')

# %%
# Predicting a new result
Y_pred = regressor.predict(X_test)
plt.scatter(Y_test, Y_pred)

# %%
sns.distplot((Y_test-Y_pred), bins =50)

# %% [markdown]
# We can observe the changes in graph of **Decision tree** from the graph of **MLR, Polynomial Regression & SVM.** We can infer that the errors have become more normalized.

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, Y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('R2 Score:', metrics.r2_score(Y_test, Y_pred))
# Out:
# Mean Absolute Error: 0.5391301365164336
# Root Mean Squared Error: 1.0782602730328665
# R2 Score: -0.09665327978580995

# %% [markdown]
# There is an increase in Mean Absolute Error and Root Mean Squared Error to a great extend & a huge decrease in **R2** score.

# %% [markdown]
# Here also a large change can be observed in the **metrics** values, by which we can conclude **Decission Tree** performed worst than **MLR, SVM and Polynomial Regression.**

# %% [markdown]
# > **Random Forest Regression**

# %%
# Fitting Random Forest Regression to the dataset
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 300, random_state = 0)
regressor.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=300, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
# Predicting a new result
Y_pred = regressor.predict(X_test)
plt.scatter(Y_test, Y_pred)

# %%
sns.distplot((Y_test-Y_pred), bins =50)

# %% [markdown]
# We can observe the changes in graph of **Random Forest Regression** from the graph of **MLR, Polynomial Regression, Decission Tree & SVM.** We can infer that the errors have become more normalized.

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, Y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('R2 Score:', metrics.r2_score(Y_test, Y_pred))
# Out:
# Mean Absolute Error: 0.6684652098911575
# Root Mean Squared Error: 0.8634892369287447
# R2 Score: 0.2967074936784173

# %% [markdown]
# The Mean Absolute Error and Root Mean Squared Error are not at there minimum after seeing the metrics of other algorithm & deccrease in **R2** score shows it didn't perform better.

# %% [markdown]
# By observing the values of **matrics** and then comparing it to the other algorithms we can clearly conclude that the **Polynomial Regression** has normalized the errors better than other algorithms and **Polynomial Regression** is the best algorithm here.
